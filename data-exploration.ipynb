# %%
import pandas as pd

#Import all dataframes needed
pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_pull_request.parquet")
repo_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_repository.parquet")
user_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_user.parquet")
pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_task_type.parquet")
pr_commit_details_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commit_details.parquet")
human_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pull_request.parquet")
human_pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pr_task_type.parquet")

#Filter PRs to have only tests PRs
test_prs = pr_task_type_df[pr_task_type_df['type'] == 'test']
pr_df = pr_df[pr_df['id'].isin(test_prs['id'])]
print('done')
# Out:
# done

# %%
print('before')
print(test_prs['agent'].value_counts())
print(pr_task_type_df['type'].value_counts())
#with pd.option_context('display.max_colwidth', None):
#    print(pr_commit_details_df[pr_commit_details_df['pr_id'].isin(test_prs['id'])].head(300))
pr_commit_details_df['isProcessed'] = False
pr_commit_details_df.head(300).to_csv("../output.csv", index=False)
print('after')
#print(pr_task_type_df[pr_task_type_df['type'] == 'test'])
# Out:
# before
# agent
# OpenAI_Codex    2029
# Copilot          167
# Devin            117
# Cursor            37
# Claude_Code        6
# Name: count, dtype: int64
# type
# feat        14450
# fix          8106
# docs         3887
# test         2356
# refactor     2288
# chore         896
# build         627
# ci            411
# perf          340
# style         188
# other          31
# revert         16
# Name: count, dtype: int64
# after

# %%
print(human_pr_task_type_df['type'].value_counts())
human_pr_test_df = human_pr_task_type_df[human_pr_task_type_df['type'] == 'test']
print(human_pr_df[human_pr_df['id'].isin(human_pr_test_df['id'])])
# Out:
# type
# feat        1946
# fix         1778
# chore        847
# build        614
# docs         519
# refactor     369
# test         183
# other        115
# ci           100
# perf          88
# style         59
# Name: count, dtype: int64
#               id  number                                              title  \
# 145   2485101244   19332  Add assertion about returning pointers in cons...
# 168   2480716143   19270  Add test for non-reified static properties on ...
# 174   2293586912   16635                 js: add buffer tests that pass now
# 184   2494821963   19426                      test-tls-root-certificates.js
# 293   2505467527    4481      chore: plugin open ai test setup and coverage
# ...          ...     ...                                                ...
# 6376  2512719139    3724        Picker - test items exists (Automation gap)
# 6447  2476163765     361            Devin/1745015016 add testing guidelines
# ...

# %%
pr_df
pr_df[pr_df['id'].isin(human_pr_test_df['id'])]
# Out:
# Empty DataFrame
# Columns: [id, number, title, body, agent, user_id, user, state, created_at, closed_at, merged_at, repo_id, repo_url, html_url]
# Index: []
